# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('football data.csv')
df
# Out:
#                        club_name            player_name   age  \
# 0             SG Wattenscheid 09        Srdjan Jankovic  32.0
# 1                  Karlsruher SC         Peter Reichert  30.0
# 2                  FC Schalke 04          Sascha Jusufi  29.0
# 3                  FC Schalke 04        Dietmar Schacht  29.0
# 4       Borussia Mönchengladbach          Norbert Meier  33.0
# ...                          ...                    ...   ...
# 170344                Venezia FC       Riccardo Pigozzo  21.0
# 170345                Venezia FC        Harvey St Clair  23.0
# 170346                Venezia FC    Lauri Ala-Myllymäki  24.0
# 170347                Venezia FC     Mirza Hasanbegovic  20.0
# 170348                Venezia FC  Mikael Törset Johnsen  21.0
#
#                   position club_involved_name            fee  \
# 0           Centre-Forward            Retired              -
# 1           Centre-Forward            Retired              -
# ...

# %%
df.size
# Out:
# 2044188

# %%
df.shape
# Out:
# (170349, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170349 entries, 0 to 170348
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   club_name           170349 non-null  object
#  1   player_name         170349 non-null  object
#  2   age                 170280 non-null  float64
#  3   position            170349 non-null  object
#  4   club_involved_name  170349 non-null  object
#  5   fee                 170236 non-null  object
#  6   transfer_movement   170349 non-null  object
#  7   transfer_period     170349 non-null  object
#  8   fee_cleaned         63721 non-null   float64
#  9   league_name         170349 non-null  object
#  10  year                170349 non-null  int64
#  11  season              170349 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 15.6+ MB

# %%
df.describe()
# Out:
#                  age   fee_cleaned           year
# count  170280.000000  63721.000000  170349.000000
# mean       24.398884      2.159418    2009.087303
# std         9.434731      6.271600       7.856204
# min         9.000000      0.000000    1992.000000
# 25%        21.000000      0.000000    2004.000000
# 50%        24.000000      0.000000    2010.000000
# 75%        27.000000      1.500000    2016.000000
# max      2011.000000    222.000000    2021.000000

# %%
df.columns
# Out:
# Index(['club_name', 'player_name', 'age', 'position', 'club_involved_name',
#        'fee', 'transfer_movement', 'transfer_period', 'fee_cleaned',
#        'league_name', 'year', 'season'],
#       dtype='object')

# %%
df.head()
# Out:
#                   club_name      player_name   age            position  \
# 0        SG Wattenscheid 09  Srdjan Jankovic  32.0      Centre-Forward
# 1             Karlsruher SC   Peter Reichert  30.0      Centre-Forward
# 2             FC Schalke 04    Sascha Jusufi  29.0            midfield
# 3             FC Schalke 04  Dietmar Schacht  29.0             defence
# 4  Borussia Mönchengladbach    Norbert Meier  33.0  Attacking Midfield
#
#   club_involved_name fee transfer_movement transfer_period  fee_cleaned  \
# 0            Retired   -               out          Summer          NaN
# 1            Retired   -               out          Summer          NaN
# 2            Retired   -               out          Summer          NaN
# 3            Retired   -               out          Summer          NaN
# 4            Retired   -               out          Summer          NaN
#
#     league_name  year     season
# 0  1 Bundesliga  1992  1992/1993
# 1  1 Bundesliga  1992  1992/1993
# ...

# %%
df.tail()
# Out:
#          club_name            player_name   age            position  \
# 170344  Venezia FC       Riccardo Pigozzo  21.0          Goalkeeper
# 170345  Venezia FC        Harvey St Clair  23.0         Left Winger
# 170346  Venezia FC    Lauri Ala-Myllymäki  24.0  Attacking Midfield
# 170347  Venezia FC     Mirza Hasanbegovic  20.0      Centre-Forward
# 170348  Venezia FC  Mikael Törset Johnsen  21.0  Attacking Midfield
#
#        club_involved_name            fee transfer_movement transfer_period  \
# 170344             Trento  loan transfer               out          Winter
# 170345          Triestina  loan transfer               out          Winter
# 170346          Triestina  loan transfer               out          Winter
# 170347       GS Kallithea  loan transfer               out          Winter
# 170348      Oakland Roots  loan transfer               out          Winter
#
#         fee_cleaned league_name  year     season
# 170344          NaN     Serie A  2021  2021/2022
# ...

# %%
df[['club_name','player_name','position','year']]
# Out:
#                        club_name            player_name            position  \
# 0             SG Wattenscheid 09        Srdjan Jankovic      Centre-Forward
# 1                  Karlsruher SC         Peter Reichert      Centre-Forward
# 2                  FC Schalke 04          Sascha Jusufi            midfield
# 3                  FC Schalke 04        Dietmar Schacht             defence
# 4       Borussia Mönchengladbach          Norbert Meier  Attacking Midfield
# ...                          ...                    ...                 ...
# 170344                Venezia FC       Riccardo Pigozzo          Goalkeeper
# 170345                Venezia FC        Harvey St Clair         Left Winger
# 170346                Venezia FC    Lauri Ala-Myllymäki  Attacking Midfield
# 170347                Venezia FC     Mirza Hasanbegovic      Centre-Forward
# 170348                Venezia FC  Mikael Törset Johnsen  Attacking Midfield
#
#         year
# 0       1992
# 1       1992
# ...

# %%
df['position'].value_counts()
# Out:
# Centre-Forward        32205
# Centre-Back           27528
# Central Midfield      17471
# Goalkeeper            16058
# Defensive Midfield    13157
# Left-Back             11302
# Attacking Midfield    10707
# Right-Back            10539
# Right Winger           8695
# Left Winger            7641
# Right Midfield         3311
# Left Midfield          3279
# midfield               2745
# Second Striker         2222
# attack                 1770
# defence                1513
# Sweeper                 206
# Name: position, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2014    8138
# 2013    7903
# 2015    7773
# 2016    7494
# 2011    7443
# 2012    7388
# 2017    7385
# 2019    7299
# 2018    7258
# 2010    7231
# 2007    6881
# 2009    6849
# 2020    6833
# 2021    6794
# 2008    6711
# 2005    6441
# 2006    6378
# 2004    6084
# 2003    4582
# 2002    4118
# 2001    3964
# 2000    3878
# 1999    3834
# 1998    3700
# 1997    3482
# 1996    3376
# 1995    3140
# 1994    2914
# 1993    2541
# 1992    2537
# Name: year, dtype: int64

# %%
df['club_name'].value_counts()
# Out:
# SL Benfica          1741
# FC Porto            1603
# Udinese Calcio      1502
# Sporting CP         1498
# SC Braga            1375
#                     ...
# KFC Uerdingen 05      15
# Alemannia Aachen      14
# CA Felgueiras         14
# FC Gueugnon           13
# Ocean Nakhodka        10
# Name: club_name, Length: 408, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 21.0      16297
# 22.0      15394
# 20.0      15356
# 23.0      14334
# 24.0      13428
# 25.0      12293
# 19.0      11998
# 26.0      11164
# 27.0      10371
# 28.0       8799
# 29.0       7629
# 18.0       6664
# 30.0       6503
# 31.0       5213
# 32.0       3942
# 33.0       2949
# 34.0       2134
# 17.0       2006
# 35.0       1361
# 36.0        864
# 37.0        501
# 16.0        405
# 38.0        265
# 39.0        158
# 40.0         92
# 15.0         46
# 41.0         45
# 42.0         19
# 43.0         14
# 44.0          8
# 14.0          7
# 45.0          5
# 12.0          3
# 11.0          3
# 2011.0        3
# 46.0          2
# 117.0         1
# 13.0          1
# 60.0          1
# 9.0           1
# 47.0          1
# Name: age, dtype: int64

# %%
df['club_involved_name'].value_counts()
# Out:
# Without Club     3733
# Retired          2366
# Inter             878
# FC Porto          845
# Benfica           821
#                  ...
# IFC Ambacht         1
# Torpedo Sochi       1
# Etar                1
# Sriwijaya FC        1
# FC Gießen           1
# Name: club_involved_name, Length: 6013, dtype: int64

# %%
df['transfer_movement'].value_counts()
# Out:
# out    88690
# in     81659
# Name: transfer_movement, dtype: int64

# %%
df['transfer_period'].value_counts()
# Out:
# Summer    125283
# Winter     45066
# Name: transfer_period, dtype: int64

# %%
df['league_name'].value_counts()
# Out:
# Serie A             27322
# Championship        23340
# Premier League      22975
# Liga Nos            20889
# Ligue 1             16768
# Primera Division    16647
# Eredivisie          14631
# Premier Liga        14284
# 1 Bundesliga        13493
# Name: league_name, dtype: int64

# %%
df[df['year']==2021].head()
# Out:
#              club_name      player_name   age          position  \
# 266        FC Augsburg  Julian Schieber  32.0    Centre-Forward
# 267         Hertha BSC     Sami Khedira  34.0  Central Midfield
# 268  Arminia Bielefeld    Reinhold Yabo  29.0  Central Midfield
# 496      Bayern Munich   Jérôme Boateng  32.0       Centre-Back
# 497      VfL Wolfsburg     Dominik Marx  21.0  Central Midfield
#
#     club_involved_name fee transfer_movement transfer_period  fee_cleaned  \
# 266            Retired   -               out          Summer          NaN
# 267            Retired   -               out          Summer          NaN
# 268            Retired   -               out          Summer          NaN
# 496       Without Club   -               out          Summer          NaN
# 497       Without Club   -               out          Summer          NaN
#
#       league_name  year     season
# 266  1 Bundesliga  2021  2021/2022
# 267  1 Bundesliga  2021  2021/2022
# ...

# %%
df[df['position']=='defence'][['year','age','club_name']].head(50)
# Out:
#        year   age                 club_name
# 3      1992  29.0             FC Schalke 04
# 17     1994  25.0                VfL Bochum
# 224    2015  19.0           SV Darmstadt 98
# 277    2000  27.0        FC Energie Cottbus
# 285    2002  30.0               Hannover 96
# 506    1992  31.0          1.FC Saarbrücken
# 519    1993  23.0          SV Werder Bremen
# 526    1994  26.0          SV Werder Bremen
# 533    1995  22.0              Hamburger SV
# 542    1995  27.0          SV Werder Bremen
# 543    1995  25.0          SV Werder Bremen
# 561    1997  29.0          SV Werder Bremen
# 562    1997  25.0             Karlsruher SC
# 572    1998  30.0          SV Werder Bremen
# 582    1999  28.0        SpVgg Unterhaching
# 891    1992  21.0        SG Wattenscheid 09
# 1045   1992  20.0          SV Werder Bremen
# 1296   1993  19.0  Borussia Mönchengladbach
# 1559   1993  18.0      VfB Leipzig (- 2004)
# 1560   1993  18.0             Karlsruher SC
# ...

# %%
df=pd.read_csv('football data.csv',index_col="club_name")
df.head(50)

# %%
df[ df['player_name']=='Cristiano Ronaldo' ]
# Out:
#                          player_name   age        position club_involved_name  \
# club_name
# Sporting CP        Cristiano Ronaldo  17.0  Centre-Forward       Sporting U19
# Sporting CP        Cristiano Ronaldo  18.0  Centre-Forward            Man Utd
# Manchester United  Cristiano Ronaldo  18.0  Centre-Forward        Sporting CP
# Manchester United  Cristiano Ronaldo  24.0  Centre-Forward        Real Madrid
# Manchester United  Cristiano Ronaldo  36.0  Centre-Forward           Juventus
# Real Madrid        Cristiano Ronaldo  24.0  Centre-Forward            Man Utd
# Real Madrid        Cristiano Ronaldo  33.0  Centre-Forward           Juventus
# Juventus FC        Cristiano Ronaldo  33.0  Centre-Forward        Real Madrid
# Juventus FC        Cristiano Ronaldo  36.0  Centre-Forward            Man Utd
#
#                         fee transfer_movement transfer_period  fee_cleaned  \
# club_name
# Sporting CP               -                in          Summer          NaN
# ...

# %%
df=pd.r

# %%
df[df['player_name']=='Lionel Messi']
# Out:
#                       player_name   age      position club_involved_name  \
# club_name
# Paris Saint-Germain  Lionel Messi  34.0  Right Winger          Barcelona
# FC Barcelona         Lionel Messi  18.0  Right Winger        Barcelona B
# FC Barcelona         Lionel Messi  34.0  Right Winger           Paris SG
#
#                                fee transfer_movement transfer_period  \
# club_name
# Paris Saint-Germain  free transfer                in          Summer
# FC Barcelona                     -                in          Summer
# FC Barcelona         free transfer               out          Summer
#
#                      fee_cleaned       league_name  year     season
# club_name
# Paris Saint-Germain          0.0           Ligue 1  2021  2021/2022
# FC Barcelona                 NaN  Primera Division  2005  2005/2006
# FC Barcelona                 0.0  Primera Division  2021  2021/2022

# %%
df[df['player_name']=='Neymar']
# Out:
#                     player_name   age     position club_involved_name  \
# club_name
# Paris Saint-Germain      Neymar  25.0  Left Winger          Barcelona
# FC Barcelona             Neymar  21.0  Left Winger          Santos FC
# FC Barcelona             Neymar  25.0  Left Winger           Paris SG
#
#                           fee transfer_movement transfer_period  fee_cleaned  \
# club_name
# Paris Saint-Germain  €222.00m                in          Summer        222.0
# FC Barcelona          €88.00m                in          Summer         88.0
# FC Barcelona         €222.00m               out          Summer        222.0
#
#                           league_name  year     season
# club_name
# Paris Saint-Germain           Ligue 1  2017  2017/2018
# FC Barcelona         Primera Division  2013  2013/2014
# FC Barcelona         Primera Division  2017  2017/2018

# %%
df.sort_values(by=['club_name','age']).head(50)
# Out:
#                         player_name   age            position  \
# club_name
# 1. FC Köln             Marco Weller  17.0  Attacking Midfield
# 1. FC Köln        Michael Gardawski  17.0       Left Midfield
# 1. FC Köln           Nikolas Nartey  17.0    Central Midfield
# 1. FC Köln            Jan Thielmann  17.0        Right Winger
# 1. FC Köln              Pablo Thiam  18.0  Defensive Midfield
# 1. FC Köln             Guido Jörres  18.0             Sweeper
# 1. FC Köln          Carsten Jancker  18.0      Centre-Forward
# 1. FC Köln           Lukas Podolski  18.0  Attacking Midfield
# 1. FC Köln             Taner Yalcin  18.0  Defensive Midfield
# 1. FC Köln         Alexander Vaaßen  18.0           Left-Back
# 1. FC Köln  Bienvenue Basala-Mazana  18.0          Right-Back
# 1. FC Köln            Reinhold Yabo  18.0    Central Midfield
# 1. FC Köln        Christian Clemens  18.0        Right Winger
# 1. FC Köln                Timo Horn  18.0          Goalkeeper
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x="age",y="year",data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()
